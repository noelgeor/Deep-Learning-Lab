# %%
# ======================================
# EXPT 1 - ANN FOR CLASSIFICATION
# Student Roll No: 24BAD083
# Name: Noel George
# ======================================

# Import Libraries
import numpy as np
import pandas as pd
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report
)

# ======================================
# Load Dataset
# ======================================

data = pd.read_csv("Breast_Cancer_Dataset.csv")

print("First 5 Rows:")
print(data.head())

print("\nDataset Shape:", data.shape)

# ======================================
# Prepare Features and Target
# ======================================

# Remove unnecessary ID column if present
if "id" in data.columns:
    data = data.drop("id", axis=1)

# Convert diagnosis column
# M = Malignant -> 0
# B = Benign -> 1
data["diagnosis"] = data["diagnosis"].map({
    "M": 0,
    "B": 1
})

# Features
X = data.drop("diagnosis", axis=1)

# Target
y = data["diagnosis"]

# ======================================
# Split Dataset
# ======================================

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# ======================================
# Standardize Features
# ======================================

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# ======================================
# Build ANN
# ======================================

model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# ======================================
# Compile Model
# ======================================

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# ======================================
# Train Model
# ======================================

history = model.fit(
    X_train,
    y_train,
    epochs=50,
    batch_size=16,
    validation_split=0.20,
    verbose=1
)

# ======================================
# Predict
# ======================================

y_pred = model.predict(X_test)

y_pred = (y_pred > 0.5).astype(int)

# ======================================
# Evaluation
# ======================================

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)

print("\n==============================")
print("Classification Results")
print("==============================")

print("Accuracy :", accuracy)
print("Precision:", precision)
print("Recall   :", recall)
print("F1 Score :", f1)

print("\nConfusion Matrix")
print(cm)

print("\nClassification Report")
print(classification_report(y_test, y_pred))
# Out:
# First 5 Rows:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# Dataset Shape: (569, 10)
# Epoch 1/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5110 - loss: 0.5999 - val_accuracy: 0.8132 - val_loss: 0.5459
# Epoch 2/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8681 - loss: 0.4742 - val_accuracy: 0.9011 - val_loss: 0.4364
# Epoch 3/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9176 - loss: 0.3711 - val_accuracy: 0.9121 - val_loss: 0.3335
# Epoch 4/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9341 - loss: 0.2820 - val_accuracy: 0.9451 - val_loss: 0.2605
# Epoch 5/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9423 - loss: 0.2211 - val_accuracy: 0.9451 - val_loss: 0.2116
# Epoch 6/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9396 - loss: 0.1824 - val_accuracy: 0.9451 - val_loss: 0.1883
# Epoch 7/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9451 - loss: 0.1613 - val_accuracy: 0.9341 - val_loss: 0.1782
# Epoch 8/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9451 - loss: 0.1492 - val_accuracy: 0.9341 - val_loss: 0.1723
# Epoch 9/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9423 - loss: 0.1409 - val_accuracy: 0.9341 - val_loss: 0.1723
# Epoch 10/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9451 - loss: 0.1349 - val_accuracy: 0.9341 - val_loss: 0.1743
# Epoch 11/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9478 - loss: 0.1306 - val_accuracy: 0.9341 - val_loss: 0.1750
# Epoch 12/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9478 - loss: 0.1260 - val_accuracy: 0.9341 - val_loss: 0.1758
# Epoch 13/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9478 - loss: 0.1230 - val_accuracy: 0.9451 - val_loss: 0.1761
# Epoch 14/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9478 - loss: 0.1209 - val_accuracy: 0.9341 - val_loss: 0.1787
# Epoch 15/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9560 - loss: 0.1180 - val_accuracy: 0.9341 - val_loss: 0.1774
# Epoch 16/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9560 - loss: 0.1159 - val_accuracy: 0.9341 - val_loss: 0.1814
# Epoch 17/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9560 - loss: 0.1131 - val_accuracy: 0.9341 - val_loss: 0.1830
# Epoch 18/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9560 - loss: 0.1118 - val_accuracy: 0.9341 - val_loss: 0.1844
# Epoch 19/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9533 - loss: 0.1092 - val_accuracy: 0.9341 - val_loss: 0.1849
# Epoch 20/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9533 - loss: 0.1090 - val_accuracy: 0.9341 - val_loss: 0.1824
# Epoch 21/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9533 - loss: 0.1062 - val_accuracy: 0.9341 - val_loss: 0.1860
# Epoch 22/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9560 - loss: 0.1048 - val_accuracy: 0.9341 - val_loss: 0.1852
# Epoch 23/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9560 - loss: 0.1038 - val_accuracy: 0.9341 - val_loss: 0.1837
# Epoch 24/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9560 - loss: 0.1028 - val_accuracy: 0.9341 - val_loss: 0.1842
# Epoch 25/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9560 - loss: 0.1016 - val_accuracy: 0.9341 - val_loss: 0.1887
# Epoch 26/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9533 - loss: 0.0995 - val_accuracy: 0.9341 - val_loss: 0.1905
# Epoch 27/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9505 - loss: 0.0987 - val_accuracy: 0.9341 - val_loss: 0.1893
# Epoch 28/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9533 - loss: 0.0978 - val_accuracy: 0.9341 - val_loss: 0.1880
# Epoch 29/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9560 - loss: 0.0962 - val_accuracy: 0.9341 - val_loss: 0.1907
# Epoch 30/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9560 - loss: 0.0958 - val_accuracy: 0.9341 - val_loss: 0.1876
# Epoch 31/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9560 - loss: 0.0951 - val_accuracy: 0.9341 - val_loss: 0.1921
# Epoch 32/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9588 - loss: 0.0932 - val_accuracy: 0.9341 - val_loss: 0.1900
# Epoch 33/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9560 - loss: 0.0929 - val_accuracy: 0.9341 - val_loss: 0.1891
# Epoch 34/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9560 - loss: 0.0918 - val_accuracy: 0.9341 - val_loss: 0.1920
# Epoch 35/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9560 - loss: 0.0911 - val_accuracy: 0.9341 - val_loss: 0.1902
# Epoch 36/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9560 - loss: 0.0912 - val_accuracy: 0.9341 - val_loss: 0.1943
# Epoch 37/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9588 - loss: 0.0891 - val_accuracy: 0.9341 - val_loss: 0.1911
# Epoch 38/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9560 - loss: 0.0889 - val_accuracy: 0.9341 - val_loss: 0.1900
# Epoch 39/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9560 - loss: 0.0886 - val_accuracy: 0.9341 - val_loss: 0.1915
# Epoch 40/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9560 - loss: 0.0882 - val_accuracy: 0.9341 - val_loss: 0.1916
# Epoch 41/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9615 - loss: 0.0862 - val_accuracy: 0.9341 - val_loss: 0.1934
# Epoch 42/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9643 - loss: 0.0853 - val_accuracy: 0.9341 - val_loss: 0.1953
# Epoch 43/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9615 - loss: 0.0849 - val_accuracy: 0.9341 - val_loss: 0.1934
# Epoch 44/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9615 - loss: 0.0845 - val_accuracy: 0.9341 - val_loss: 0.1946
# Epoch 45/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9643 - loss: 0.0835 - val_accuracy: 0.9231 - val_loss: 0.1987
# Epoch 46/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9698 - loss: 0.0821 - val_accuracy: 0.9341 - val_loss: 0.1933
# Epoch 47/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9643 - loss: 0.0825 - val_accuracy: 0.9341 - val_loss: 0.1958
# Epoch 48/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9643 - loss: 0.0812 - val_accuracy: 0.9341 - val_loss: 0.1904
# Epoch 49/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9670 - loss: 0.0802 - val_accuracy: 0.9231 - val_loss: 0.1991
# Epoch 50/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9670 - loss: 0.0793 - val_accuracy: 0.9231 - val_loss: 0.1971
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# ==============================
# Classification Results
# ==============================
# Accuracy : 0.9824561403508771
# Precision: 0.9726027397260274
# Recall   : 1.0
# F1 Score : 0.9861111111111112
#
# Confusion Matrix
# [[41  2]
#  [ 0 71]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.98        43
#            1       0.97      1.00      0.99        71
#
#     accuracy                           0.98       114
#    macro avg       0.99      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114
